# %% [markdown]
# To apply Naive Bayes classification in this scenario, we need to calculate the likelihoods and prior probabilities for each class. Since the prior probabilities are assumed to be equal for each class, we don't need to consider them in the comparison.
#
# Let's denote the new instance with features X1 = 3 and X2 = 4 as (3, 4).
#
# The Naive Bayes classification involves calculating the following probabilities for each class (A and B) and selecting the class with the higher probability:
#
# �
# (
# �
# ∣
# (
# 3
# ,
# 4
# )
# )
# ∝
# �
# (
# �
# 1
# =
# 3
# ∣
# �
# )
# ⋅
# �
# (
# �
# 2
# =
# 4
# ∣
# �
# )
# P(A∣(3,4))∝P(X1=3∣A)⋅P(X2=4∣A)
# �
# (
# �
# ∣
# (
# 3
# ,
# 4
# )
# )
# ∝
# �
# (
# �
# 1
# =
# 3
# ∣
# �
# )
# ⋅
# �
# (
# �
# 2
# =
# 4
# ∣
# �
# )
# P(B∣(3,4))∝P(X1=3∣B)⋅P(X2=4∣B)
#
# The symbol "
# ∝
# ∝" means "proportional to."
#
# Let's calculate these probabilities using the provided frequency table:
#
# For class A:
# �
# (
# �
# 1
# =
# 3
# ∣
# �
# )
# =
# 4
# 10
# P(X1=3∣A)=
# 10
# 4
# ​
#
# �
# (
# �
# 2
# =
# 4
# ∣
# �
# )
# =
# 3
# 10
# P(X2=4∣A)=
# 10
# 3
# ​
#
#
# For class B:
# �
# (
# �
# 1
# =
# 3
# ∣
# �
# )
# =
# 1
# 7
# P(X1=3∣B)=
# 7
# 1
# ​
#
# �
# (
# �
# 2
# =
# 4
# ∣
# �
# )
# =
# 3
# 7
# P(X2=4∣B)=
# 7
# 3
# ​
#
#
# Now, calculate the proportional probabilities for each class:
# �
# (
# �
# ∣
# (
# 3
# ,
# 4
# )
# )
# ∝
# 4
# 10
# ⋅
# 3
# 10
# P(A∣(3,4))∝
# 10
# 4
# ​
#  ⋅
# 10
# 3
# ​
#
# �
# (
# �
# ∣
# (
# 3
# ,
# 4
# )
# )
# ∝
# 1
# 7
# ⋅
# 3
# 7
# P(B∣(3,4))∝
# 7
# 1
# ​
#  ⋅
# 7
# 3
# ​
#
#
# Now, you can compare these probabilities. The class with the higher proportional probability is the predicted class. Calculate the final probabilities and choose the class accordingly.
