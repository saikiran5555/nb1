# %% [markdown]
# Bayes' theorem is closely related to conditional probability. In fact, Bayes' theorem can be derived from the definition of conditional probability. Let's explore this relationship:
#
# The conditional probability of event A given event B, denoted as
# �
# (
# �
# ∣
# �
# )
# P(A∣B), is the probability of A occurring given that B has occurred. Bayes' theorem provides a way to update this conditional probability based on new information.
#
# The formula for conditional probability is:
#
# �
# (
# �
# ∣
# �
# )
# =
# �
# (
# �
# ∩
# �
# )
# �
# (
# �
# )
# P(A∣B)=
# P(B)
# P(A∩B)
# ​
#
#
# Here,
# �
# (
# �
# ∩
# �
# )
# P(A∩B) represents the probability of both events A and B occurring.
#
# Now, Bayes' theorem introduces a relationship between conditional probabilities:
#
# �
# (
# �
# ∣
# �
# )
# =
# �
# (
# �
# ∣
# �
# )
# ⋅
# �
# (
# �
# )
# �
# (
# �
# )
# P(A∣B)=
# P(B)
# P(B∣A)⋅P(A)
# ​
#
#
# In this formula:
#
# �
# (
# �
# ∣
# �
# )
# P(B∣A) is the probability of event B occurring given that event A has occurred.
# �
# (
# �
# )
# P(A) is the prior probability of event A.
# �
# (
# �
# )
# P(B) is the prior probability of event B.
